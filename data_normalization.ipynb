# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('security-log.csv', sep=';', header=None)

# %%
def cut_string(x, char, pos=0):
    if type(x) == str:
        return x.split(char)[pos]
    else:
        return x

df.columns = [df[col].apply(lambda x: cut_string(x, char='=', pos=0)).dropna().unique()[0] for col in df.columns]
df = df.applymap(lambda x: cut_string(x, char='=', pos=1))

df.head()
# Out:
#         itime        date      time             devid    vd type   subtype  \
# 0  1562794099  2019-07-10  23:28:18  FWF40C3915001580  root  utm  app-ctrl
# 1  1562794099  2019-07-10  23:28:18  FWF40C3915001580  root  utm  app-ctrl
# 2  1562793794  2019-07-10  23:23:15  FWF40C3915001580  root  utm  app-ctrl
# 3  1562793673  2019-07-10  23:21:15  FWF40C3915001580  root  utm  app-ctrl
# 4  1562793673  2019-07-10  23:21:15  FWF40C3915001580  root  utm  app-ctrl
#
#   action          app           appcat ...  logver  \
# 0   pass  SSL_TLSv1.2  Network.Service ...      52
# 1   pass          SSL  Network.Service ...      52
# 2   pass          NTP  Network.Service ...      52
# 3   pass       iCloud   Storage.Backup ...      52
# 4   pass  SSL_TLSv1.2  Network.Service ...      52
#
#                                msg policyid proto service sessionid srcintf  \
# 0  "Network.Service: SSL_TLSv1.2,"        3     6   HTTPS    165147    wan1
# 1          "Network.Service: SSL,"        3     6   HTTPS    165147    wifi
# 2          "Network.Service: NTP,"        3    17     NTP    164878    wifi
# 3        "Storage.Backup: iCloud,"        3     6   HTTPS    164786    wan1
# 4  "Network.Service: SSL_TLSv1.2,"        3     6   HTTPS    164786    wan1
#
#           srcip srcport  url
# 0  192.168.52.2   60599    /
# 1  192.168.52.2   60599    /
# 2  192.168.52.2   55484  NaN
# 3  192.168.52.2   60598    /
# 4  192.168.52.2   60598    /
#
# [5 rows x 33 columns]
