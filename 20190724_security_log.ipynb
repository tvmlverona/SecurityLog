# %% [markdown]
# # Kaggle courses
#
# # Lesson: Data Visualization: From Non-Coder to Coder!
#
#
# First of all upload the dataset "security-log.csv"

# %%
# Set up the notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
sec_filepath = "/content/20190711_security-log.csv"
# header=none: insert the index at the top of the matrix
df = pd.read_csv(sec_filepath, sep=';', header=None)

# %%
def cut_string(x, char, pos=0):
    if type(x) == str:
        return x.split(char)[pos]
    else:
        return x

# lambda: funtion in line
#df.columns = [df[col].apply(lambda x: cut_string(x, char='=', pos=0)).dropna().unique()[0] for col in df.columns]

df.head()
# Out:
#                  0                1   ...             31     32
# 0  itime=1562794099  date=2019-07-10  ...  srcport=60599  url=/
# 1  itime=1562794099  date=2019-07-10  ...  srcport=60599  url=/
# 2  itime=1562793794  date=2019-07-10  ...  srcport=55484    NaN
# 3  itime=1562793673  date=2019-07-10  ...  srcport=60598  url=/
# 4  itime=1562793673  date=2019-07-10  ...  srcport=60598  url=/
#
# [5 rows x 33 columns]

# %%
columns=[]
#columns=list()
for col in df.columns:
  print(col)
#  print(df.index)
#  print(df.loc[:10].index)
  series=df[col].copy()
#  series=df.loc[:10,col].copy()
#  print(series)
  for row in df.index:
#  for row in df.loc[:10].index:
#    print(row)
    series[row]=cut_string(df.loc[row,col],'=',0)
  series.dropna(inplace=True)
  list_cols=series.unique()
  print(list_cols)
  if len(list_cols) > 0:
    columns.append(list_cols[0])
  else:
    columns.append(f'hidden_{col}')
print(columns)
df.colums=columns
# Out:
# 0
# ['itime']
# 1
# ['date']
# 2
# ['time']
# 3
# ['devid']
# 4
# ['vd']
# 5
# ['type']
# 6
# ['subtype']
# 7
# ['action']
# 8
# ['app']
# 9
# ['appcat']
# 10
# ['appid']
# 11
# ['applist']
# 12
# ['apprisk']
# 13
# ['crlevel']
# 14
# ['crscore']
# 15
# ['dstintf']
# 16
# ['dstip']
# 17
# ['dstname']
# 18
# ['dstport']
# 19
# ['eventtype']
# 20
# ['hostname']
# 21
# ['level']
# 22
# ['logid']
# 23
# ['logver']
# 24
# ['msg']
# 25
# ['policyid']
# 26
# ['proto']
# 27
# ['service']
# 28
# ['sessionid']
# 29
# ['srcintf']
# 30
# ['srcip']
# 31
# ['srcport']
# 32
# ['url']
# ['itime', 'date', 'time', 'devid', 'vd', 'type', 'subtype', 'action', 'app', 'appcat', 'appid', 'applist', 'apprisk', 'crlevel', 'crscore', 'dstintf', 'dstip', 'dstname', 'dstport', 'eventtype', 'hostname', 'level', 'logid', 'logver', 'msg', 'policyid', 'proto', 'service', 'sessionid', 'srcintf', 'srcip', 'srcport', 'url']
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
df.columns=columns
df = df.applymap(lambda x: cut_string(x, char='=', pos=1))

#exercise: detail the last instruction

# %%
df.tail()
# Out:
#            itime        date      time  ...         srcip srcport  url
# 7361  1562570745  2019-07-06  12:08:54  ...  192.168.52.2   57877    /
# 7362  1562570745  2019-07-06  12:08:54  ...  192.168.52.2   57876    /
# 7363  1562570745  2019-07-06  12:08:54  ...  192.168.52.2   57875    /
# 7364  1562570745  2019-07-06  12:08:40  ...  192.168.52.2   56642  NaN
# 7365  1562570745  2019-07-06  12:08:40  ...  192.168.52.2   59278  NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# # Data elaboration
#
#
# 0. data cleaning; for example: the first cleaning should be on the unreachable or incorrect hostname
# 1. select the most interesting colums
# 2. for each column indentify if there is an interesting graph to plot
# 3. group the values of each of these columns to obtain a classification to plot (for example the most common source IP, especially from the pubblic net)
# 4. identifying relationships among the original columns or the columns classificated
# 5. identifying not accessible url parsing the output of the http call
# 6. identifying the meaning of the accessible urls
# 7. thinking to a first neural network application
# 8. other ideas

# %% [markdown]
# data cleaning; for example: the first cleaning should be on the unreachable or incorrect hostname
#
# for each column indentify if there is an interesting graph to plot
#
# group the values of each of these columns to obtain a classification to plot (for example the most common source IP, especially from the pubblic net)
#
# identifying relationships among the original columns or the columns classificated
#
# identifying not accessible url parsing the output of the http call
#
# identifying the meaning of the accessible urls
#
# thinking to a first neural network application
#
# other ideas

# %%
df.head()
# Out:
#         itime        date      time  ...         srcip srcport  url
# 0  1562794099  2019-07-10  23:28:18  ...  192.168.52.2   60599    /
# 1  1562794099  2019-07-10  23:28:18  ...  192.168.52.2   60599    /
# 2  1562793794  2019-07-10  23:23:15  ...  192.168.52.2   55484  NaN
# 3  1562793673  2019-07-10  23:21:15  ...  192.168.52.2   60598    /
# 4  1562793673  2019-07-10  23:21:15  ...  192.168.52.2   60598    /
#
# [5 rows x 33 columns]

# %% [markdown]
# Select the most interesting colums

# %%
df.columns.tolist()
# Out:
# ['itime',
#  'date',
#  'time',
#  'devid',
#  'vd',
#  'type',
#  'subtype',
#  'action',
#  'app',
#  'appcat',
#  'appid',
#  'applist',
#  'apprisk',
#  'crlevel',
#  'crscore',
#  'dstintf',
#  'dstip',
#  'dstname',
#  'dstport',
#  'eventtype',
#  'hostname',
#  'level',
#  'logid',
#  'logver',
#  'msg',
#  'policyid',
#  'proto',
#  'service',
#  'sessionid',
#  'srcintf',
#  'srcip',
#  'srcport',
#  'url']

# %%
interesting_columns=[
 'date',
 'time',
 'app',
 'appcat',
  'apprisk',
 'crlevel',
 'crscore',
 'dstintf',
 'dstip',
 'dstname',
 'dstport',
 'hostname',
 'level',
 'logid',
 'logver',
 'msg',
 'proto',
 'service',
 'sessionid',
 'srcintf',
 'srcip',
 'srcport',
 'url']

# %% [markdown]
# Create a new dataset keeping the interesting_columns only

# %%
df1 = df[interesting_columns]

# %% [markdown]
# Generic infographic of the new dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7366 entries, 0 to 7365
# Data columns (total 33 columns):
# itime        7366 non-null object
# date         7366 non-null object
# time         7366 non-null object
# devid        7366 non-null object
# vd           7366 non-null object
# type         7366 non-null object
# subtype      7366 non-null object
# action       7366 non-null object
# app          7366 non-null object
# appcat       7366 non-null object
# appid        7366 non-null object
# applist      7366 non-null object
# apprisk      7313 non-null object
# crlevel      10 non-null object
# crscore      10 non-null object
# dstintf      7366 non-null object
# dstip        7366 non-null object
# dstname      467 non-null object
# dstport      7366 non-null object
# eventtype    7366 non-null object
# hostname     6474 non-null object
# level        7366 non-null object
# logid        7366 non-null object
# logver       7366 non-null object
# msg          7366 non-null object
# policyid     7366 non-null object
# proto        7366 non-null object
# service      7366 non-null object
# sessionid    7366 non-null object
# srcintf      7366 non-null object
# srcip        7366 non-null object
# srcport      7366 non-null object
# url          6474 non-null object
# dtypes: object(33)
# memory usage: 1.9+ MB

# %%
print(len(df1))
df1.info()
# Out:
# 7366
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7366 entries, 0 to 7365
# Data columns (total 23 columns):
# date         7366 non-null object
# time         7366 non-null object
# app          7366 non-null object
# appcat       7366 non-null object
# apprisk      7313 non-null object
# crlevel      10 non-null object
# crscore      10 non-null object
# dstintf      7366 non-null object
# dstip        7366 non-null object
# dstname      467 non-null object
# dstport      7366 non-null object
# hostname     6474 non-null object
# level        7366 non-null object
# logid        7366 non-null object
# logver       7366 non-null object
# msg          7366 non-null object
# proto        7366 non-null object
# service      7366 non-null object
# sessionid    7366 non-null object
# srcintf      7366 non-null object
# srcip        7366 non-null object
# srcport      7366 non-null object
# url          6474 non-null object
# dtypes: object(23)
# memory usage: 1.3+ MB

# %%
df1.describe()
# Out:
#               date      time   app  ...         srcip srcport   url
# count         7366      7366  7366  ...          7366    7366  6474
# unique           4      2243    42  ...             6    3984    76
# top     2019-07-09  07:10:31   SSL  ...  192.168.52.2   50499     /
# freq          3035        49  2455  ...          3563      34  6322
#
# [4 rows x 23 columns]

# %%
#?sns.heatmap()
df1.isnull()
# Out:
#        date   time    app  appcat  ...  srcintf  srcip  srcport    url
# 0     False  False  False   False  ...    False  False    False  False
# 1     False  False  False   False  ...    False  False    False  False
# 2     False  False  False   False  ...    False  False    False   True
# 3     False  False  False   False  ...    False  False    False  False
# 4     False  False  False   False  ...    False  False    False  False
# 5     False  False  False   False  ...    False  False    False  False
# 6     False  False  False   False  ...    False  False    False   True
# 7     False  False  False   False  ...    False  False    False   True
# 8     False  False  False   False  ...    False  False    False   True
# 9     False  False  False   False  ...    False  False    False  False
# 10    False  False  False   False  ...    False  False    False  False
# 11    False  False  False   False  ...    False  False    False   True
# 12    False  False  False   False  ...    False  False    False   True
# 13    False  False  False   False  ...    False  False    False   True
# 14    False  False  False   False  ...    False  False    False   True
# 15    False  False  False   False  ...    False  False    False  False
# 16    False  False  False   False  ...    False  False    False  False
# 17    False  False  False   False  ...    False  False    False   True
# 18    False  False  False   False  ...    False  False    False   True
# 19    False  False  False   False  ...    False  False    False   True
# 20    False  False  False   False  ...    False  False    False   True
# 21    False  False  False   False  ...    False  False    False   True
# 22    False  False  False   False  ...    False  False    False   True
# 23    False  False  False   False  ...    False  False    False   True
# 24    False  False  False   False  ...    False  False    False   True
# 25    False  False  False   False  ...    False  False    False   True
# 26    False  False  False   False  ...    False  False    False   True
# 27    False  False  False   False  ...    False  False    False   True
# 28    False  False  False   False  ...    False  False    False   True
# 29    False  False  False   False  ...    False  False    False   True
# ...     ...    ...    ...     ...  ...      ...    ...      ...    ...
# 7336  False  False  False   False  ...    False  False    False  False
# 7337  False  False  False   False  ...    False  False    False  False
# 7338  False  False  False   False  ...    False  False    False  False
# 7339  False  False  False   False  ...    False  False    False  False
# 7340  False  False  False   False  ...    False  False    False  False
# 7341  False  False  False   False  ...    False  False    False  False
# 7342  False  False  False   False  ...    False  False    False  False
# 7343  False  False  False   False  ...    False  False    False  False
# 7344  False  False  False   False  ...    False  False    False  False
# 7345  False  False  False   False  ...    False  False    False  False
# 7346  False  False  False   False  ...    False  False    False  False
# 7347  False  False  False   False  ...    False  False    False  False
# 7348  False  False  False   False  ...    False  False    False  False
# 7349  False  False  False   False  ...    False  False    False  False
# 7350  False  False  False   False  ...    False  False    False  False
# 7351  False  False  False   False  ...    False  False    False  False
# 7352  False  False  False   False  ...    False  False    False  False
# 7353  False  False  False   False  ...    False  False    False  False
# 7354  False  False  False   False  ...    False  False    False  False
# 7355  False  False  False   False  ...    False  False    False  False
# 7356  False  False  False   False  ...    False  False    False  False
# 7357  False  False  False   False  ...    False  False    False  False
# 7358  False  False  False   False  ...    False  False    False  False
# 7359  False  False  False   False  ...    False  False    False  False
# 7360  False  False  False   False  ...    False  False    False  False
# 7361  False  False  False   False  ...    False  False    False  False
# 7362  False  False  False   False  ...    False  False    False  False
# 7363  False  False  False   False  ...    False  False    False  False
# 7364  False  False  False   False  ...    False  False    False   True
# 7365  False  False  False   False  ...    False  False    False   True
#
# [7366 rows x 23 columns]

# %% [markdown]
# Missing values using heatmap

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Security Log")

# Heatmap showing 
sns.heatmap(data=df1.isnull(), annot=False)

# Add label for horizontal axis
plt.xlabel("Log Lines")
# Out:
# Text(0.5, 42.0, 'Log Lines')

# %%
df2_suspect = df1.dropna(subset=["crlevel","crscore"], axis=0)
df2_suspect
# Out:
#             date      time         app  ...         srcip srcport  url
# 1913  2019-07-10  13:36:18  BitTorrent  ...  192.168.53.2   54117  NaN
# 4140  2019-07-09  22:51:11  BitTorrent  ...  192.168.53.2   53597  NaN
# 4245  2019-07-09  21:32:53  BitTorrent  ...  192.168.53.2   53539  NaN
# 4452  2019-07-09  20:11:36  BitTorrent  ...  192.168.53.2   53123  NaN
# 4465  2019-07-09  20:09:15  BitTorrent  ...  192.168.53.2   53119  NaN
# 4470  2019-07-09  20:08:47  BitTorrent  ...  192.168.53.2   53114  NaN
# 4516  2019-07-09  19:28:27  BitTorrent  ...  192.168.53.2   53106  NaN
# 4601  2019-07-09  18:06:36  BitTorrent  ...  192.168.53.2   53075  NaN
# 5299  2019-07-09  08:04:10  BitTorrent  ...  192.168.53.3   55724  NaN
# 5398  2019-07-09  07:52:10  BitTorrent  ...  192.168.53.2   52547  NaN
#
# [10 rows x 23 columns]

# %%
df2_suspect.sort_values(by=["date","time"], inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2_suspect
# Out:
#             date      time         app  ...         srcip srcport  url
# 5398  2019-07-09  07:52:10  BitTorrent  ...  192.168.53.2   52547  NaN
# 5299  2019-07-09  08:04:10  BitTorrent  ...  192.168.53.3   55724  NaN
# 4601  2019-07-09  18:06:36  BitTorrent  ...  192.168.53.2   53075  NaN
# 4516  2019-07-09  19:28:27  BitTorrent  ...  192.168.53.2   53106  NaN
# 4470  2019-07-09  20:08:47  BitTorrent  ...  192.168.53.2   53114  NaN
# 4465  2019-07-09  20:09:15  BitTorrent  ...  192.168.53.2   53119  NaN
# 4452  2019-07-09  20:11:36  BitTorrent  ...  192.168.53.2   53123  NaN
# 4245  2019-07-09  21:32:53  BitTorrent  ...  192.168.53.2   53539  NaN
# 4140  2019-07-09  22:51:11  BitTorrent  ...  192.168.53.2   53597  NaN
# 1913  2019-07-10  13:36:18  BitTorrent  ...  192.168.53.2   54117  NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# Imputation of missing values (for example:  'crlevel', 'crscore')

# %%
for col in ["crlevel","crscore","dstname"]:
  print(col,df1[col].dropna().unique(),len(df1[col].dropna().unique()))
# Out:
# crlevel ['low'] 1
# crscore ['5'] 1
# dstname ['mil04s27-in-f3.1e100.net' 'mil04s29-in-f195.1e100.net'
#  'mil04s26-in-f99.1e100.net' 'mil04s26-in-f110.1e100.net'
#  'mil04s04-in-f14.1e100.net' 'mil04s25-in-f3.1e100.net'
#  'mil04s28-in-f162.1e100.net' 'mil04s29-in-f4.1e100.net' '93.184.220.29'
#  'mil04s04-in-f35.1e100.net' 'mil04s27-in-f14.1e100.net'
#  'mil04s27-in-f10.1e100.net' 'mil04s29-in-f206.1e100.net'
#  'mil04s27-in-f4.1e100.net' 'mil04s26-in-f10.1e100.net'
#  'mil04s26-in-f104.1e100.net' '13.107.4.50' 'mil04s03-in-f3.1e100.net'
#  'mil04s28-in-f4.1e100.net' 'mil04s03-in-f14.1e100.net'
#  'mil04s28-in-f14.1e100.net'
#  'a104-83-88-10.deploy.static.akamaitechnologies.com'
#  'ocsp.sc.intesasanpaolo.infocert.it' 'ws19414012241.fujitsu.es'
#  '37.157.4.24' 'mil04s25-in-f78.1e100.net'
#  'a95-101-180-177.deploy.static.akamaitechnologies.com'
#  'defra3-vip-bx-008.aaplimg.com'
#  'a88-221-111-48.deploy.static.akamaitechnologies.com' '83.224.68.148'
#  'a95-101-180-176.deploy.static.akamaitechnologies.com' '83.224.68.144'
#  'a104-104-54-203.deploy.static.akamaitechnologies.com'
#  'a88-221-111-51.deploy.static.akamaitechnologies.com'
#  'a104-104-55-41.deploy.static.akamaitechnologies.com'
#  'mil04s25-in-f14.1e100.net' 'defra3-vip-bx-001.aaplimg.com'
#  'mil04s25-in-f4.1e100.net' 'mil04s27-in-f142.1e100.net'
#  'mil04s04-in-f46.1e100.net' 'mil04s26-in-f3.1e100.net' '83.224.68.152'
#  'mil04s28-in-f174.1e100.net' '151.139.128.14'
#  'defra3-vip-bx-006.aaplimg.com' 'defra1-vip-bx-008.aaplimg.com'
#  'server-99-86-163-89.mxp64.r.cloudfront.net'
#  'server-99-86-163-84.mxp64.r.cloudfront.net' 'mil04s25-in-f67.1e100.net'
#  'server-99-86-163-15.mxp64.r.cloudfront.net'
#  'server-99-86-163-105.mxp64.r.cloudfront.net'
#  'whatsapp-chatd-edge-shv-01-mxp1.facebook.com'
#  'mil04s29-in-f14.1e100.net' '83.224.68.147' 'mil04s29-in-f3.1e100.net'
#  'mil04s04-in-f4.1e100.net' '93.184.221.240'
#  'a92-122-145-12.deploy.static.akamaitechnologies.com'
#  'mil04s27-in-f131.1e100.net'
#  'a92-123-180-203.deploy.static.akamaitechnologies.com'] 60

# %%
for col in ["crlevel","crscore","dstname"]:
  print(col,df1[col].value_counts())
# Out:
# crlevel low    10
# Name: crlevel, dtype: int64
# crscore 5    10
# Name: crscore, dtype: int64
# dstname a104-83-88-10.deploy.static.akamaitechnologies.com      38
# mil04s26-in-f110.1e100.net                              33
# mil04s03-in-f14.1e100.net                               24
# mil04s04-in-f14.1e100.net                               21
# mil04s27-in-f14.1e100.net                               20
# mil04s27-in-f142.1e100.net                              20
# mil04s29-in-f195.1e100.net                              19
# mil04s28-in-f14.1e100.net                               18
# mil04s25-in-f78.1e100.net                               15
# 83.224.68.147                                           14
# a95-101-180-177.deploy.static.akamaitechnologies.com    14
# mil04s26-in-f99.1e100.net                               12
# mil04s04-in-f46.1e100.net                               11
# defra3-vip-bx-001.aaplimg.com                           11
# mil04s04-in-f35.1e100.net                               10
# mil04s29-in-f206.1e100.net                              10
# 93.184.220.29                                           10
# mil04s25-in-f4.1e100.net                                10
# mil04s27-in-f4.1e100.net                                 9
# mil04s26-in-f10.1e100.net                                9
# a95-101-180-176.deploy.static.akamaitechnologies.com     9
# mil04s28-in-f174.1e100.net                               8
# 151.139.128.14                                           7
# 83.224.68.144                                            7
# mil04s26-in-f104.1e100.net                               6
# defra3-vip-bx-006.aaplimg.com                            6
# mil04s25-in-f3.1e100.net                                 6
# mil04s26-in-f3.1e100.net                                 6
# mil04s29-in-f14.1e100.net                                5
# mil04s28-in-f4.1e100.net                                 5
# mil04s25-in-f67.1e100.net                                5
# mil04s27-in-f10.1e100.net                                5
# mil04s28-in-f162.1e100.net                               4
# defra3-vip-bx-008.aaplimg.com                            4
# server-99-86-163-89.mxp64.r.cloudfront.net               4
# mil04s25-in-f14.1e100.net                                4
# mil04s03-in-f3.1e100.net                                 4
# 83.224.68.148                                            3
# mil04s27-in-f3.1e100.net                                 3
# mil04s29-in-f3.1e100.net                                 3
# 93.184.221.240                                           3
# mil04s04-in-f4.1e100.net                                 3
# 83.224.68.152                                            2
# server-99-86-163-84.mxp64.r.cloudfront.net               2
# 37.157.4.24                                              2
# a88-221-111-48.deploy.static.akamaitechnologies.com      2
# whatsapp-chatd-edge-shv-01-mxp1.facebook.com             2
# server-99-86-163-105.mxp64.r.cloudfront.net              2
# defra1-vip-bx-008.aaplimg.com                            2
# ocsp.sc.intesasanpaolo.infocert.it                       2
# server-99-86-163-15.mxp64.r.cloudfront.net               2
# a104-104-55-41.deploy.static.akamaitechnologies.com      2
# mil04s29-in-f4.1e100.net                                 2
# ws19414012241.fujitsu.es                                 1
# a88-221-111-51.deploy.static.akamaitechnologies.com      1
# a92-123-180-203.deploy.static.akamaitechnologies.com     1
# a92-122-145-12.deploy.static.akamaitechnologies.com      1
# 13.107.4.50                                              1
# mil04s27-in-f131.1e100.net                               1
# a104-104-54-203.deploy.static.akamaitechnologies.com     1
# Name: dstname, dtype: int64

# %% [markdown]
# Extract occurrences for the following columns:
# - destip
# - sessionid
# - app
# - srcip
# - service
# - hostname

# %%
for col in ["dstip","sessionid","app","srcip","service","hostname"]:
  print(col,df1[col].value_counts())
# Out:
# dstip 79.7.90.141        562
# 192.168.1.203      357
# 17.253.54.125      233
# 156.54.131.85      183
# 104.83.88.10       160
# 99.86.163.101      159
# 99.86.163.110      132
# 17.242.57.246      111
# 40.67.252.61       102
# 52.0.252.24        101
# 31.13.86.8          81
# 31.13.86.36         57
# 213.227.153.240     56
# 157.240.193.63      55
# 157.240.193.16      52
# 37.10.0.96          50
# 99.86.163.121       49
# 104.244.39.20       48
# 2.20.158.32         48
# 31.13.86.2          48
# 52.0.253.129        46
# 216.58.205.106      46
# 17.250.13.5         44
# 104.83.154.143      42
# 216.58.205.138      42
# 216.58.205.110      40
# 216.58.205.142      40
# 69.173.144.140      40
# 216.58.205.194      39
# 17.142.171.15       38
#                   ...
# 208.91.112.52        1
# 92.122.145.12        1
# 2.20.86.37           1
# 52.21.30.251         1
# 173.194.151.186      1
# 104.83.89.175        1
# 67.27.225.254        1
# 2.20.157.101         1
# 173.194.162.72       1
# 104.244.42.136       1
# 52.109.76.40         1
# 143.204.15.100       1
# 74.125.111.167       1
# 40.80.145.78         1
# 40.90.23.210         1
# 8.8.8.8              1
# 194.140.12.241       1
# 40.90.23.242         1
# 74.125.111.156       1
# 216.58.198.54        1
# 95.101.180.193       1
# 173.194.60.170       1
# 143.204.15.73        1
# 99.86.163.20         1
# 40.90.23.218         1
# 173.194.187.105      1
# 99.86.163.28         1
# 173.194.190.103      1
# 104.244.42.8         1
# 172.217.4.195        1
# Name: dstip, Length: 716, dtype: int64
# sessionid 141488    34
# 95892     30
# 157974    17
# 110766    14
# 115037    11
# 117968     7
# 85504      5
# 96929      5
# 144590     5
# 88146      4
# 109941     3
# 123775     3
# 129231     3
# 106831     3
# 106834     3
# 98217      3
# 125057     3
# 156544     3
# 122830     3
# 130785     3
# 157910     3
# 141107     3
# 160941     3
# 97135      3
# 99583      3
# 99684      3
# 153500     3
# 146754     3
# 128038     3
# 158812     3
#           ..
# 86039      1
# 85844      1
# 96915      1
# 97519      1
# 108993     1
# 82797      1
# 157500     1
# 85843      1
# 138351     1
# 121559     1
# 160970     1
# 162301     1
# 134447     1
# 121910     1
# 121515     1
# 151186     1
# 108083     1
# 121802     1
# 151968     1
# 158295     1
# 96303      1
# 562        1
# 136299     1
# 121623     1
# 151088     1
# 160815     1
# 148041     1
# 156817     1
# 84800      1
# 109789     1
# Name: sessionid, Length: 4310, dtype: int64
# app SSL                            2455
# SSL_TLSv1.2                    2371
# Viber                           603
# SNMP_GetRequest                 271
# NTP                             235
# YouTube                         220
# Facebook                        190
# iCloud                          136
# Apple.iOS.Push.Notification     131
# Instagram                        83
# SNMP_V1                          76
# Google.Services                  73
# Microsoft.Portal                 68
# OCSP                             54
# Apple.Iphone                     51
# Skype                            43
# WhatsApp                         36
# Google.Accounts                  33
# Apple.Store                      28
# IMAPS                            28
# SSL_TLSv1.0                      27
# MS.Windows.Update                21
# Twitter                          20
# Microsoft.Authentication         13
# SNMP_GetNextRequest              10
# Google.Ads                       10
# BitTorrent                       10
# SSL_TLSv1.1                       9
# HTTP.Audio                        8
# Microsoft.Office.Online           8
# Facebook_Video.Play               7
# Apple.Ipad                        6
# Google.Calendar                   6
# HTTP.Segmented.Download           5
# Spotify                           4
# Google.Analytics                  3
# Vkontakte                         3
# SSL_SSLv3                         3
# Ping                              3
# HTTP.Download.Accelerator         3
# Apple.Software.Update             1
# Google.Drive                      1
# Name: app, dtype: int64
# srcip 192.168.52.2      3563
# 192.168.53.2      1700
# 192.168.52.3      1227
# 192.168.53.3       805
# 192.168.51.100      62
# 192.168.53.4         9
# Name: srcip, dtype: int64
# service HTTPS        5964
# tcp/5223      390
# SNMP          357
# NTP           235
# HTTP          161
# tcp/4244      126
# IMAPS          56
# DNS            36
# tcp/5228       19
# tcp/5222       10
# tcp/10443       8
# PING            3
# tcp/5242        1
# Name: service, dtype: int64
# hostname zenetto.readynet.it                562
# courier.push.apple.com             393
# gateway.icloud.com                 284
# media.cdn.viber.com                166
# dl-media.viber.com                 166
# www.larena.it                      161
# gs-loc.apple.com                   130
# mesu.apple.com                     130
# api-glb-fra.smoot.apple.com         87
# gsp10-ssl.apple.com                 86
# iphone-xml.booking.com              84
# dt.adsafeprotected.com              80
# youtubei.googleapis.com             78
# init.itunes.apple.com               76
# xp.apple.com                        76
# ib.adnxs.com                        74
# fastlane.rubiconproject.com         70
# neudb5-client-s.gateway.messeng     68
# p26-buy.itunes.apple.com            64
# content.cdn.viber.com               56
# scontent-fco1-1.cdninstagram.co     55
# www3.smartadserver.com              54
# market.viber.com                    51
# safebrowsing.googleapis.com         50
# *.googleapis.com                    49
# edge-mqtt.facebook.com              48
# googleads.g.doubleclick.net         46
# setup.icloud.com                    45
# b1t-euc1.zemanta.com                44
# guzzoni.apple.com                   44
#                                   ...
# secure.booking.com                   2
# appldnld.apple.com                   1
# r6---sn-hpa7znsl.googlevideo.co      1
# scontent-mxp1-1.xx.fbcdn.net         1
# prod8.do.dsp.mp.microsoft.com        1
# r2---sn-h5q7knee.googlevideo.co      1
# download.windowsupdate.com           1
# r1---sn-hpa7znss.googlevideo.co      1
# video-mxp1-1.xx.fbcdn.net            1
# lh4.googleusercontent.com            1
# ocsp.camerfirma.com                  1
# r4---sn-4g5e6n7r.googlevideo.co      1
# ocsp.comodoca4.com                   1
# invite.viber.com                     1
# r4---sn-4g5e6nsr.googlevideo.co      1
# r2---sn-vgqsknel.googlevideo.co      1
# fmfmobile.icloud.com                 1
# r2---sn-hpa7znsk.googlevideo.co      1
# news.mybooker.it                     1
# ton.twimg.com                        1
# *.c.docs.google.com                  1
# dmd.metaservices.microsoft.com       1
# configprd.samsungcloudsolution.      1
# mrodevicemgr.officeapps.live.co      1
# r4---sn-5ualdn7z.googlevideo.co      1
# availability.icloud.com              1
# abtest.api.viber.com                 1
# *.doubleclick.net                    1
# r2---sn-25glenez.googlevideo.co      1
# drive.google.com                     1
# Name: hostname, Length: 419, dtype: int64

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=7366, step=1)

# %% [markdown]
# Plot the different occurences

# %%
df1.columns
# Out:
# Index(['date', 'time', 'app', 'appcat', 'apprisk', 'crlevel', 'crscore',
#        'dstintf', 'dstip', 'dstname', 'dstport', 'hostname', 'level', 'logid',
#        'logver', 'msg', 'proto', 'service', 'sessionid', 'srcintf', 'srcip',
#        'srcport', 'url'],
#       dtype='object')

# %%
df1.values
# Out:
# array([['2019-07-10', '23:28:18', 'SSL_TLSv1.2', ..., '192.168.52.2',
#         '60599', '/'],
#        ['2019-07-10', '23:28:18', 'SSL', ..., '192.168.52.2', '60599',
#         '/'],
#        ['2019-07-10', '23:23:15', 'NTP', ..., '192.168.52.2', '55484',
#         nan],
#        ...,
#        ['2019-07-06', '12:08:54', 'YouTube', ..., '192.168.52.2',
#         '57875', '/'],
#        ['2019-07-06', '12:08:40', 'NTP', ..., '192.168.52.2', '56642',
#         nan],
#        ['2019-07-06', '12:08:40', 'NTP', ..., '192.168.52.2', '59278',
#         nan]], dtype=object)

# %%
df1[["dstip"]]
# Out:
#                dstip
# 0     17.248.146.168
# 1     17.248.146.168
# 2      17.253.54.125
# 3     17.248.146.168
# 4     17.248.146.168
# 5     17.248.146.168
# 6        79.7.90.137
# 7        79.7.90.137
# 8      192.168.1.203
# 9        79.7.90.137
# 10       79.7.90.137
# 11     192.168.1.203
# 12     192.168.1.203
# 13     192.168.1.203
# 14      40.67.252.61
# 15      40.67.252.61
# 16      40.67.252.61
# 17     192.168.1.203
# 18     192.168.1.203
# 19     192.168.1.203
# 20     192.168.1.203
# 21     192.168.1.203
# 22     192.168.1.203
# 23     192.168.1.203
# 24     192.168.1.203
# 25     192.168.1.203
# 26     192.168.1.203
# 27     192.168.1.203
# 28     192.168.1.203
# 29     192.168.1.203
# ...              ...
# 7336  104.83.154.143
# 7337     79.7.90.141
# 7338     79.7.90.141
# 7339  17.167.194.149
# 7340  17.167.194.149
# 7341    17.252.28.73
# 7342    17.252.28.73
# 7343    17.252.28.73
# 7344  95.101.180.176
# 7345  17.252.194.199
# 7346  17.252.194.199
# 7347  216.58.205.202
# 7348  216.58.205.202
# 7349  216.58.205.202
# 7350    17.252.92.24
# 7351    17.252.92.24
# 7352    17.252.92.24
# 7353   83.224.68.151
# 7354  95.101.180.176
# 7355   216.58.198.46
# 7356   216.58.198.46
# 7357     23.33.6.135
# 7358     23.33.6.135
# 7359  104.83.154.143
# 7360     23.33.6.135
# 7361     23.33.6.135
# 7362  104.83.154.143
# 7363  216.58.205.174
# 7364         1.1.1.7
# 7365         1.1.1.7
#
# [7366 rows x 1 columns]

# %%
 df1.iloc[3]
# Out:
# date                        2019-07-10
# time                          23:21:15
# app                             iCloud
# appcat                  Storage.Backup
# apprisk                         medium
# crlevel                            NaN
# crscore                            NaN
# dstintf                           wifi
# dstip                   17.248.146.168
# dstname                            NaN
# dstport                            443
# hostname            gateway.icloud.com
# level                      information
# logid                            28704
# logver                              52
# msg          "Storage.Backup: iCloud,"
# proto                                6
# service                          HTTPS
# sessionid                       164786
# srcintf                           wan1
# srcip                     192.168.52.2
# srcport                          60598
# url                                  /
# Name: 3, dtype: object

# %%
# transform the dataframe in an matrix of 2 columns: dstip and the count of the dstip
#df3={'dstip' : df1["dstip"], 'dstip_count' : df1["dstip"].value_counts()}
df3={'dstip_count' : df1["dstip"].value_counts()}
df4 = pd.DataFrame(df3)[:10]
#df4 = pd.DataFrame(df3)
df4
# Out:
#                dstip_count
# 79.7.90.141            562
# 192.168.1.203          357
# 17.253.54.125          233
# 156.54.131.85          183
# 104.83.88.10           160
# 99.86.163.101          159
# 99.86.163.110          132
# 17.242.57.246          111
# 40.67.252.61           102
# 52.0.252.24            101

# %%
x4=df4.index
y4=df4["dstip_count"]
#plt.figure(figsize=(10,5))
chart = sns.scatterplot(x4, y4)
#chart = sns.countplot(
#    data=data[data['Year'] == 1980],
#    x='Sport',
#    palette='Set1'
#)
#chart
#chart.set_xticklabels(chart.get_xticklabels(),rotation=45,horizontalalignment='right')
#chart.set_xticklabels('ddd',rotation=45,horizontalalignment='right')
#chart.get_xticklabels()
plt.xticks(rotation=45,horizontalalignment='right');

# %%
chart = sns.barplot(x4, y4)
plt.xticks(rotation=45,horizontalalignment='right');

# %%
# transform the dataframe in an matrix of 2 columns: dstip and the count of the dstip
df5={'app_count' : df1["app"].value_counts()}
df6 = pd.DataFrame(df5)[:10]
df6
# Out:
#                              app_count
# SSL                               2455
# SSL_TLSv1.2                       2371
# Viber                              603
# SNMP_GetRequest                    271
# NTP                                235
# YouTube                            220
# Facebook                           190
# iCloud                             136
# Apple.iOS.Push.Notification        131
# Instagram                           83

# %%
sns.scatterplot(x=df6.index, y=df6["app_count"])
plt.xticks(rotation=90,horizontalalignment='right');

# %%
chart = sns.barplot(x=df6.index, y=df6["app_count"])
plt.xticks(rotation=45,horizontalalignment='right');

# %% [markdown]
# Extract occurrences for the following columns:
#
# time slot (4; 0-6, 7-12, 13-18, 19-24) on "time" columns
#
# for each time sloc compute la frequency of the single service
#
#   x: time slot
#
#   y: frequency
#
#   color (label): service

# %%
#df['time'] = pd.to_timedelta(df['time'],unit='s')
df['time'] = pd.to_datetime(df['time'])
df['hours'] = df['time'].dt.hour
#data=df.groupby([pd.Grouper(key='time',freq='H'),'app'])['app'].agg({'freq':'count'}).reset_index()
data=df.groupby(['hours','app'])['app'].agg({'freq':'count'}).reset_index()
#data=data.pivot(index='time',columns='app',values='freq').fillna(0)
data=data.pivot(index='hours',columns='app',values='freq').fillna(0)
data.head()
#df['hours'].unique()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   after removing the cwd from sys.path.
# app    Apple.Ipad  Apple.Iphone  ...  YouTube  iCloud
# hours                            ...
# 0             0.0           1.0  ...      0.0     9.0
# 1             0.0           2.0  ...      0.0     6.0
# 2             0.0           0.0  ...      0.0     4.0
# 3             0.0           5.0  ...      0.0    11.0
# 4             0.0           1.0  ...      0.0     6.0
#
# [5 rows x 42 columns]

# %%
highest_freq_app=data.sum().sort_values(ascending=False).apply(lambda x: x if x>200 else np.nan).dropna().index

# %%
plt.figure(figsize=(14,6))
#sns.lineplot(data=data.loc[:,highest_freq_app])
sns.lineplot(data=data.iloc[:,:6])
plt.xlabel("Hours")
#plt.xticks(pd.to_datetime(data.index))
# Out:
# Text(0.5, 0, 'Hours')
